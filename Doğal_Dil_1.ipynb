# %% [markdown]
# <a href="https://colab.research.google.com/github/gulendamcinar/hu_bby_261/blob/main/Do%C4%9Fal_Dil_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dil tespiti için kelime listeleri
diller = {
    "Türkçe": {
        "karakterler": "çğışöü",
        "kelimeler": [
            "ve", "bir", "bu", "için", "ama", "ile", "değil", "var", "o", "ne",
            "gibi", "çok", "her", "ben", "sen", "biz", "siz", "onlar", "bu", "da",
            "kadar", "olarak", "yok", "evet", "hayır", "neden", "ne", "ne zaman",
            "yine", "şey", "sonra", "görmek", "bunu", "önce", "çünkü", "ama", "birçok",
            "diğer", "fakat", "daha", "geçmek", "işte", "böyle", "kendisi", "olmak",
            "yeni", "uzun", "kısa", "belirli", "güzel", "çalışmak", "bulmak", "düşünmek",
            "gitmek", "gelmek", "göstermek", "biliyorum", "bilmiyorum", "istiyorum", "duymak",
            "yakın", "uzak", "büyük", "küçük", "görmek", "girmek", "kalkmak", "biri",
            "herkes", "sürekli", "zaman", "yer", "neden", "şimdi", "belki", "sadece",
            "görüşmek", "arasında", "gün", "ay", "yıl", "dönmek", "belli", "tanımak",
            "günlük", "öğrenmek", "alışmak", "bağlantı", "fırsat", "zamanında", "eğitim",
            "plan", "geri", "gidiş", "mesaj", "eski", "yeni", "görünüş", "çalışan",
            "hayat", "diğer", "yakın", "çevre", "katılmak", "geliyorum", "toplantı",
            "merhaba", "nasılsınız", "iyi", "bunu", "herhangi", "yapmak", "şu", "ne kadar",
            "iş", "selam", "hoşça kal", "görüşürüz", "seni seviyorum", "aşk", "canım",
            "sevgilim", "güle güle", "iyi akşamlar", "günaydın", "bir", "iki", "üç", "dört",
            "beş", "yemek", "beyaz", "mavi", "yeşil", "kırmızı", "yavaş", "hızlı", "soğuk",
            "sıcak", "et", "sebze", "meyve", "elma", "armut", "biber", "soğan", "domates",
            "salata", "ekmek", "çay", "kahve", "su", "pilav", "tavuk", "balık", "patates",
            "yatak", "masa", "sandalye", "kitap", "telefon", "kapı", "pencere", "hava",
            "bulutlu", "yağmur", "kar", "güneşli","iyi geceler"
        ]
    },
    "İngilizce": {
        "karakterler": "",
        "kelimeler": [
            "the", "is", "in", "and", "of", "to", "with", "on", "this", "that",
            "for", "a", "an", "it", "he", "she", "we", "they", "at", "by", "be",
            "have", "do", "can", "will", "just", "as", "from", "not", "but", "who",
            "there", "all", "how", "where", "when", "my", "his", "her", "your",
            "we", "they", "it’s", "its", "was", "were", "are", "been", "being",
            "have", "has", "had", "doing", "done", "doing", "be", "do", "did",
            "does", "doesn’t", "hasn’t", "haven’t", "that", "these", "those", "there",
            "was", "were", "because", "although", "despite", "however", "more", "less",
            "much", "few", "many", "some", "any", "each", "every", "still", "really",
            "quite", "very", "just", "already", "never", "always", "before", "after",
            "yet", "soon", "soon", "soon", "lately", "finally", "first", "second",
            "third", "next", "new", "old", "young", "different", "same", "long", "short",
            "hello", "goodbye", "love", "hugs", "kiss", "miss", "good night", "good morning",
            "how are you", "I love you", "sweetheart", "dear", "hey", "bye", "take care",
            "one", "two", "three", "four", "five", "food", "white", "blue", "green",
            "red", "slow", "fast", "cold", "hot", "meat", "vegetable", "fruit", "apple",
            "pear", "pepper", "onion", "tomato", "salad", "bread", "tea", "coffee", "water",
            "rice", "chicken", "fish", "potato", "bed", "table", "chair", "book", "phone",
            "door", "window", "weather", "cloudy", "rain", "snow", "sunny"
        ]
    },
    "Almanca": {
        "karakterler": "äöüß",
        "kelimeler": [
            "der", "die", "das", "und", "in", "zu", "mit", "von", "auf", "für",
            "ist", "war", "sind", "haben", "sein", "werden", "auch", "aber", "ich",
            "du", "er", "sie", "wir", "ihr", "sie", "nicht", "noch", "vor", "nach",
            "jetzt", "immer", "man", "welche", "wird", "dass", "es", "dies", "jeder",
            "niemand", "etwas", "viel", "wenig", "mehr", "bitte", "danke", "guten",
            "morgen", "abend", "lang", "kurz", "schön", "nein", "ja", "möchten", "essen",
            "trinken", "gehen", "kommen", "sehen", "hören", "denken", "finden", "fragen",
            "antworten", "arbeiten", "lernen", "lesen", "schreiben", "leben", "tot",
            "freund", "freundin", "haus", "auto", "straße", "kind", "hund", "katze",
            "alle", "dieser", "welcher", "zuerst", "nachdem", "immer", "schnell",
            "hallo", "tschüss", "liebe", "küsse", "vermissen", "gute nacht", "guten morgen",
            "wie geht's", "ich liebe dich", "mein Schatz", "liebling", "eins", "zwei",
            "drei", "vier", "fünf", "essen", "weiß", "blau", "grün", "rot", "lang",
            "kurz", "kalt", "heiß", "fleisch", "gemüse", "frucht", "apfel", "birne",
            "pfeffer", "zwiebel", "tomate", "salat", "brot", "tee", "kaffee", "wasser",
            "reis", "huhn", "fisch", "kartoffel", "bett", "tisch", "stuhl", "buch",
            "telefon", "tür", "fenster", "wetter", "bewölkt", "regen", "schnee", "sonnig"
        ]
    },
    "Fransızca": {
        "karakterler": "éèçàô",
        "kelimeler": [
            "le", "la", "les", "un", "une", "et", "dans", "avec", "pour", "sur",
            "est", "sont", "avoir", "être", "faire", "dire", "avoir", "être", "cela",
            "ce", "je", "tu", "il", "elle", "nous", "vous", "ils", "elles", "non",
            "oui", "mais", "quand", "où", "comment", "pourquoi", "ceci", "cela",
            "tout", "rien", "beaucoup", "trop", "peu", "toujours", "jamais", "souvent",
            "parfois", "parler", "aimer", "comprendre", "regarder", "voir", "entendre",
            "comprendre", "venir", "aller", "demander", "répondre", "savoir", "dire",
            "les", "quel", "quelles", "voilà", "bonjour", "au revoir", "je t'aime",
            "bisous", "ça va", "mon amour", "chéri", "salut", "à bientôt", "bonne nuit",
            "bon matin", "amour", "bisous", "chérie", "tendre", "un", "deux", "trois",
            "quatre", "cinq", "manger", "blanc", "bleu", "vert", "rouge", "long",
            "court", "froid", "chaud", "viande", "légume", "fruit", "pomme", "poire",
            "poivron", "oignon", "tomate", "salade", "pain", "thé", "café", "eau",
            "riz", "poulet", "poisson", "pomme de terre", "lit", "table", "chaise",
            "livre", "téléphone", "porte", "fenêtre", "temps", "nuageux", "pluie", "neige",
            "ensoleillé"
        ]
    },
    "İspanyolca": {
        "karakterler": "ñáéíóú",
        "kelimeler": [
            "el", "la", "los", "las", "un", "una", "y", "en", "por", "para",
            "es", "son", "está", "tener", "ser", "hacer", "decir", "este", "esto",
            "yo", "tú", "él", "ella", "nosotros", "vosotros", "ellos", "no", "sí",
            "pero", "cuando", "donde", "por qué", "porque", "aunque", "si", "nunca",
            "mucho", "poco", "alguien", "nadie", "todo", "algo", "aquí", "allí",
            "cerca", "lejos", "bueno", "malo", "nuevo", "viejo", "grande", "pequeño",
            "fácil", "difícil", "mejor", "peor", "gracias", "por favor", "hola", "adiós",
            "te quiero", "besos", "abrazo", "te extraño", "buenas noches", "buenos días",
            "cómo estás", "uno", "dos", "tres", "cuatro", "cinco", "comer", "blanco",
            "azul", "verde", "rojo", "lento", "rápido", "frío", "caliente", "carne",
            "vegetal", "fruta", "manzana", "pera", "pimiento", "cebolla", "tomate", "ensalada",
            "pan", "té", "café", "agua", "arroz", "pollo", "pescado", "patata", "cama",
            "mesa", "silla", "libro", "teléfono", "puerta", "ventana", "tiempo", "nublado",
            "lluvia", "nieve", "soleado"
        ]
    }
}

def dil_tespiti(metin):
    # Küçük harfe çevirme
    metin = metin.lower()

    # Her dil için kelimeleri sayma
    dil_puanları = {dil: 0 for dil in diller}

    for dil, bilgiler in diller.items():
        kelimeler = bilgiler["kelimeler"]
        for kelime in kelimeler:
            if kelime in metin:
                dil_puanları[dil] += 1

    # En yüksek puanı alan dili döndür
    en_iyi_dil = max(dil_puanları, key=dil_puanları.get)

    # Eğer tüm dillerin puanı 0 ise, dil tespiti yapılamaz
    if dil_puanları[en_iyi_dil] == 0:
        return "Dil tespit edilemedi"

    return en_iyi_dil

# Kullanıcıdan metin al
metin = input("Bir metin girin: ")
print(f"Tespit edilen dil: {dil_tespiti(metin)}")
# Out:
# Bir metin girin: Je vais préparer un délicieux repas ce soir pour mes amis et nous allons passer une soirée agréable ensemble
# Tespit edilen dil: Fransızca
